# %% [markdown]
# # <span style="color:#312e81; font-weight:600;">Analiza Danych (Python) Lekcja 1 - Organizacja i wprowadzenie
#
# 1. [Organizacja](#1.-Organizacja)
# 2. [Materiały](#2.-Materiały)
# 3. [Dokumentacja bibliotek](#3.-Dokumentacja-bibliotek)
# 5. [Wirtualne środowisko](#4.-Wirtualne-środowisko)
# 6. [Github](#5.-Github)
# 7. [Import danych](#6.-Import-danych)

# %% [markdown]
# ## <span style="color:#312e81; font-weight:600;">1. Organizacja

# %% [markdown]
# ## <span style="color:#312e81; font-weight:600;">2. Materiały

# %% [markdown]
#  ## <span style="color:#312e81; font-weight:600;">3. Dokumentacja bibliotek

# %% [markdown]
# ## <span style="color:#312e81; font-weight:600;">4. Wirtualne środowisko

# %% [markdown]
# ## <span style="color:#312e81; font-weight:600;">5. Github

# %% [markdown]
# ## <span style="color:#312e81; font-weight:600;">6. Import danych
